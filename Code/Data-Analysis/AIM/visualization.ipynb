# %%
import matplotlib.pyplot as plt
import csv

x1 = []

# mus musculus
#Publications with strong Disease-Associations
y1 = []
#Publications with weak Disease-Associations
y2 = []
#Publications with Same-Classification
y3 = []
#Publications with Different-Classification
y4 = []

# homo sapiens
#Publications with strong Disease-Associations
y5 = []
#Publications with weak Disease-Associations
y6 = []
#Publications with Same-Classification
y7 = []
#Publications with Different-Classification
y8 = []

# mus musculus & homo sapiens
#Publications with strong Disease-Associations
y9 = []
#Publications with weak Disease-Associations
y10 = []
#Publications with Same-Classification
y11 = []
#Publications with Different-Classification
y12 = []

with open('aim_4.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x1.append(int(row[0]))
        # mus musculus - Disease association
        y1.append(int(row[4]))
        y2.append(int(row[5]))
        # mus musculus - Overall call
        y3.append(int(row[12]))
        y4.append(int(row[13]))
        # homo sapiens - Disease association
        y5.append(int(row[6]))
        y6.append(int(row[7]))
        # homo sapiens - Overall call
        y7.append(int(row[14]))
        y8.append(int(row[15]))
        # homo sapiens and mus musculus - Disease association
        y9.append(int(row[8]))
        y10.append(int(row[9]))
        # homo sapiens and mus musculus - Overall call
        y11.append(int(row[16]))
        y12.append(int(row[17]))

fig = plt.figure(figsize=(9, 2))

fig.suptitle('')

rows = 1
columns = 3

grid = plt.GridSpec(rows, columns, wspace = .5, hspace = .5)

plt.subplot(grid[0, 0])
plt.plot(x1, y1, color='black', label='Publications with strong Disease-Associations')
plt.plot(x1, y2, color='green', label='Publications with weak Disease-Associations')
plt.plot(x1, y3, color='blue', label='Publications with Same-Classification')
plt.plot(x1, y4, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Mus Musculus')

plt.subplot(grid[0, 1])
plt.plot(x1, y5, color='black', label='Publications with strong Disease-Associations')
plt.plot(x1, y6, color='green', label='Publications with weak Disease-Associations')
plt.plot(x1, y7, color='blue', label='Publications with Same-Classification')
plt.plot(x1, y8, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Homo Sapiens')

plt.subplot(grid[0, 2])
plt.plot(x1, y9, color='black', label='Publications with strong Disease-Associations')
plt.plot(x1, y10, color='green', label='Publications with weak Disease-Associations')
plt.plot(x1, y11, color='blue', label='Publications with Same-Classification')
plt.plot(x1, y12, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Homo Sapiens & Mus Musculus')

plt.legend(loc="lower center", bbox_to_anchor=(-1, -1))

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

# Disease association
y2 = []
y3 = []

y4 = []
y5 = []

y6 = []
y7 = []

y8 = []
y9 = []

# Overall call
y10 = []
y11 = []

y12 = []
y13 = []

y14 = []
y15 = []

y16 = []
y17 = []


with open('aim_3.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))

        
        # all species - Disease association
        y2.append(int(row[2]))
        y3.append(int(row[3]))

        # mus musculus - Disease association
        y4.append(int(row[4]))
        y5.append(int(row[5]))

        # homo sapiens - Disease association
        y6.append(int(row[6]))
        y7.append(int(row[7]))

        # homo sapiens and mus musculus - Disease association
        y8.append(int(row[8]))
        y9.append(int(row[9]))

        
        # all species - Overall call
        y10.append(int(row[10]))
        y11.append(int(row[11]))

        # mus musculus - Overall call
        y12.append(int(row[12]))
        y13.append(int(row[13]))

        # homo sapiens - Overall call
        y14.append(int(row[14]))
        y15.append(int(row[15]))

        # homo sapiens and mus musculus - Overall call
        y16.append(int(row[16]))
        y17.append(int(row[17]))

#plt.plot(x,y, label='All PubMed publications')


# Disease association
#plt.plot(x,y2, label='Publications (Strong Disease-Association, All species)')
#plt.plot(x,y3, label='Publications (Weak Disease-Association, All species)')

plt.plot(x,y4, label='Publications (Strong Disease-Association, Mus Musculus)')
plt.plot(x,y5, label='Publications (Weak Disease-Association, Mus Musculus)')

#plt.plot(x,y6, label='Publications (Strong Disease-Association, Homo Sapiens)')
#plt.plot(x,y7, label='Publications (Weak Disease-Association, Homo Sapiens)')

#plt.plot(x,y8, label='Publications (Strong Disease-Association, Mus Musculus & Homo Sapiens)')
#plt.plot(x,y9, label='Publications (Weak Disease-Association, Mus Musculus & Homo Sapiens)')


# Overall call
#plt.plot(x,y10, label='Publications (Same-Classification, All species)')
#plt.plot(x,y11, label='Publications (Different-Classification, All species)')

plt.plot(x,y12, label='Publications (Same-Classification, Mus Musculus)')
plt.plot(x,y13, label='Publications (Different-Classification, Mus Musculus)')

#plt.plot(x,y14, label='Publications (Same-Classification, Homo Sapiens)')
#plt.plot(x,y15, label='Publications (Different-Classification, Homo Sapiens)')

#plt.plot(x,y16, label='Publications (Same-Classification, Mus Musculus & Homo Sapiens)')
#plt.plot(x,y17, label='Publications (Different-Classification, Mus Musculus & Homo Sapiens)')


plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('# of publications by year')


plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.6))
plt.show()

# %%
# Mus Musculus

#testis
#liver
#kidney
#heart
#cerebellum
#brain

#Publications with strong Disease-Associations
#Publications with weak Disease-Associations
#Publications with Same-Classification
#Publications with Different-Classification

import csv

# mus musculus Index
index_Strong_DiseaseAssociation = 4
index_Weak_DiseaseAssociation = 5
index_Strong_Call = 12
index_Weak_Call = 13

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(11, 11))

fig.suptitle('Mus musculus')

rows = 3
columns = 2

grid = plt.GridSpec(rows, columns, wspace = .5, hspace = .5)

#testis
x1 = []
#Publications with strong Disease-Associations
y1 = []
#Publications with weak Disease-Associations
y2 = []
#Publications with Same-Classification
y3 = []
#Publications with Different-Classification
y4 = []

with open('testis_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x1.append(int(row[0]))
        # Disease association
        y1.append(int(row[index_Strong_DiseaseAssociation]))
        y2.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y3.append(int(row[index_Strong_Call]))
        y4.append(int(row[index_Weak_Call]))
        
plt.subplot(grid[0, 0])
plt.plot(x1, y1, color='black', label='Publications with strong Disease-Associations')
plt.plot(x1, y2, color='green', label='Publications with weak Disease-Associations')
plt.plot(x1, y3, color='blue', label='Publications with Same-Classification')
plt.plot(x1, y4, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Testis')

     
#liver
x2 = []
#Publications with strong Disease-Associations
y5 = []
#Publications with weak Disease-Associations
y6 = []
#Publications with Same-Classification
y7 = []
#Publications with Different-Classification
y8 = []

with open('liver_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:   
        x2.append(int(row[0]))
        # Disease association
        y5.append(int(row[index_Strong_DiseaseAssociation]))
        y6.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y7.append(int(row[index_Strong_Call]))
        y8.append(int(row[index_Weak_Call]))

plt.subplot(grid[0, 1])
plt.plot(x2, y5, color='black', label='Publications with strong Disease-Associations')
plt.plot(x2, y6, color='green', label='Publications with weak Disease-Associations')
plt.plot(x2, y7, color='blue', label='Publications with Same-Classification')
plt.plot(x2, y8, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Liver')
   
    
#kidney
x3 = []
#Publications with strong Disease-Associations
y9 = []
#Publications with weak Disease-Associations
y10 = []
#Publications with Same-Classification
y11 = []
#Publications with Different-Classification
y12 = []

with open('kidney_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots: 
        x3.append(int(row[0]))
        # Disease association
        y9.append(int(row[index_Strong_DiseaseAssociation]))
        y10.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y11.append(int(row[index_Strong_Call]))
        y12.append(int(row[index_Weak_Call]))
        
plt.subplot(grid[1, 0])
plt.plot(x3, y9, color='black', label='Publications with strong Disease-Associations')
plt.plot(x3, y10, color='green', label='Publications with weak Disease-Associations')
plt.plot(x3, y11, color='blue', label='Publications with Same-Classification')
plt.plot(x3, y12, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Kidney')

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -1))
        

#heart
x4 = []
#Publications with strong Disease-Associations
y13 = []
#Publications with weak Disease-Associations
y14 = []
#Publications with Same-Classification
y15 = []
#Publications with Different-Classification
y16 = []

with open('heart_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:  
        x4.append(int(row[0]))
        # Disease association
        y13.append(int(row[index_Strong_DiseaseAssociation]))
        y14.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y15.append(int(row[index_Strong_Call]))
        y16.append(int(row[index_Weak_Call]))
        
plt.subplot(grid[1, 1])
plt.plot(x4, y13, color='black', label='Publications with strong Disease-Associations')
plt.plot(x4, y14, color='green', label='Publications with weak Disease-Associations')
plt.plot(x4, y15, color='blue', label='Publications with Same-Classification')
plt.plot(x4, y16, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Heart')
        

#cerebellum
#x5 = []
#Publications with strong Disease-Associations
#y17 = []
#Publications with weak Disease-Associations
#y18 = []
#Publications with Same-Classification
#y19 = []
#Publications with Different-Classification
#y20 = []

#with open('cerebellum_aim2.tsv','r') as csvfile:
    #plots = csv.reader(csvfile, delimiter='\t')
    #for row in plots:   
        #x5.append(int(row[0]))
        # Disease association
        #y17.append(int(row[index_Strong_DiseaseAssociation]))
        #y18.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        #19.append(int(row[index_Strong_Call]))
        #20.append(int(row[index_Weak_Call]))
        
#plt.subplot(grid[2, 0])
#plt.plot(x5, y17, color='black', label='Publications with strong Disease-Associations')
#plt.plot(x5, y18, color='green', label='Publications with weak Disease-Associations')
#plt.plot(x5, y19, color='blue', label='Publications with Same-Classification')
#plt.plot(x5, y20, color='orange', label='Publications with Different-Classification')
#plt.xlabel('Year')
#plt.ylabel('# of publications')
#plt.title('Cerebellum')
        

#brain
x6 = []
#Publications with strong Disease-Associations
y21 = []
#Publications with weak Disease-Associations
y22 = []
#Publications with Same-Classification
y23 = []
#Publications with Different-Classification
y24 = []

with open('brain_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots: 
        x6.append(int(row[0]))
        # Disease association
        y21.append(int(row[index_Strong_DiseaseAssociation]))
        y22.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y23.append(int(row[index_Strong_Call]))
        y24.append(int(row[index_Weak_Call]))

plt.subplot(grid[2, 1])
plt.plot(x6, y21, color='black', label='Publications with strong Disease-Associations')
plt.plot(x6, y22, color='green', label='Publications with weak Disease-Associations')
plt.plot(x6, y23, color='blue', label='Publications with Same-Classification')
plt.plot(x6, y24, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Brain')
# Out:
# Text(0.5, 1.0, 'Brain')

# %%
# Homo sapiens

#testis
#liver
#kidney
#heart
#cerebellum
#brain

#Publications with strong Disease-Associations
#Publications with weak Disease-Associations
#Publications with Same-Classification
#Publications with Different-Classification

import csv

# homo sapiens Index
index_Strong_DiseaseAssociation = 6
index_Weak_DiseaseAssociation = 7
index_Strong_Call = 14
index_Weak_Call = 15

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(11, 11))

fig.suptitle('Homo Sapiens')

rows = 3
columns = 2

grid = plt.GridSpec(rows, columns, wspace = .5, hspace = .5)

#testis
x1 = []
#Publications with strong Disease-Associations
y1 = []
#Publications with weak Disease-Associations
y2 = []
#Publications with Same-Classification
y3 = []
#Publications with Different-Classification
y4 = []

with open('testis_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x1.append(int(row[0]))
        # Disease association
        y1.append(int(row[index_Strong_DiseaseAssociation]))
        y2.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y3.append(int(row[index_Strong_Call]))
        y4.append(int(row[index_Weak_Call]))
        
plt.subplot(grid[0, 0])
plt.plot(x1, y1, color='black', label='Publications with strong Disease-Associations')
plt.plot(x1, y2, color='green', label='Publications with weak Disease-Associations')
plt.plot(x1, y3, color='blue', label='Publications with Same-Classification')
plt.plot(x1, y4, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Testis')

     
#liver
x2 = []
#Publications with strong Disease-Associations
y5 = []
#Publications with weak Disease-Associations
y6 = []
#Publications with Same-Classification
y7 = []
#Publications with Different-Classification
y8 = []

with open('liver_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:   
        x2.append(int(row[0]))
        # Disease association
        y5.append(int(row[index_Strong_DiseaseAssociation]))
        y6.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y7.append(int(row[index_Strong_Call]))
        y8.append(int(row[index_Weak_Call]))

plt.subplot(grid[0, 1])
plt.plot(x2, y5, color='black', label='Publications with strong Disease-Associations')
plt.plot(x2, y6, color='green', label='Publications with weak Disease-Associations')
plt.plot(x2, y7, color='blue', label='Publications with Same-Classification')
plt.plot(x2, y8, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Liver')
   
    
#kidney
x3 = []
#Publications with strong Disease-Associations
y9 = []
#Publications with weak Disease-Associations
y10 = []
#Publications with Same-Classification
y11 = []
#Publications with Different-Classification
y12 = []

with open('kidney_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots: 
        x3.append(int(row[0]))
        # Disease association
        y9.append(int(row[index_Strong_DiseaseAssociation]))
        y10.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y11.append(int(row[index_Strong_Call]))
        y12.append(int(row[index_Weak_Call]))
        
plt.subplot(grid[1, 0])
plt.plot(x3, y9, color='black', label='Publications with strong Disease-Associations')
plt.plot(x3, y10, color='green', label='Publications with weak Disease-Associations')
plt.plot(x3, y11, color='blue', label='Publications with Same-Classification')
plt.plot(x3, y12, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Kidney')

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -1))
        

#heart
x4 = []
#Publications with strong Disease-Associations
y13 = []
#Publications with weak Disease-Associations
y14 = []
#Publications with Same-Classification
y15 = []
#Publications with Different-Classification
y16 = []

with open('heart_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:  
        x4.append(int(row[0]))
        # Disease association
        y13.append(int(row[index_Strong_DiseaseAssociation]))
        y14.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y15.append(int(row[index_Strong_Call]))
        y16.append(int(row[index_Weak_Call]))
        
plt.subplot(grid[1, 1])
plt.plot(x4, y13, color='black', label='Publications with strong Disease-Associations')
plt.plot(x4, y14, color='green', label='Publications with weak Disease-Associations')
plt.plot(x4, y15, color='blue', label='Publications with Same-Classification')
plt.plot(x4, y16, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Heart')
        

#cerebellum
#x5 = []
#Publications with strong Disease-Associations
#y17 = []
#Publications with weak Disease-Associations
#y18 = []
#Publications with Same-Classification
#y19 = []
#Publications with Different-Classification
#y20 = []

#with open('cerebellum_aim2.tsv','r') as csvfile:
    #plots = csv.reader(csvfile, delimiter='\t')
    #for row in plots:   
        #x5.append(int(row[0]))
        # Disease association
        #y17.append(int(row[index_Strong_DiseaseAssociation]))
        #y18.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        #y19.append(int(row[index_Strong_Call]))
        #y20.append(int(row[index_Weak_Call]))
        
#plt.subplot(grid[2, 0])
#plt.plot(x5, y17, color='black', label='Publications with strong Disease-Associations')
#plt.plot(x5, y18, color='green', label='Publications with weak Disease-Associations')
#plt.plot(x5, y19, color='blue', label='Publications with Same-Classification')
#plt.plot(x5, y20, color='orange', label='Publications with Different-Classification')
#plt.xlabel('Year')
#plt.ylabel('# of publications')
#plt.title('Cerebellum')
        

#brain
x6 = []
#Publications with strong Disease-Associations
y21 = []
#Publications with weak Disease-Associations
y22 = []
#Publications with Same-Classification
y23 = []
#Publications with Different-Classification
y24 = []

with open('brain_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots: 
        x6.append(int(row[0]))
        # Disease association
        y21.append(int(row[index_Strong_DiseaseAssociation]))
        y22.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y23.append(int(row[index_Strong_Call]))
        y24.append(int(row[index_Weak_Call]))

plt.subplot(grid[2, 1])
plt.plot(x6, y21, color='black', label='Publications with strong Disease-Associations')
plt.plot(x6, y22, color='green', label='Publications with weak Disease-Associations')
plt.plot(x6, y23, color='blue', label='Publications with Same-Classification')
plt.plot(x6, y24, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Brain')
# Out:
# Text(0.5, 1.0, 'Brain')

# %%
# Homo sapiens & mus musculus

#testis
#liver
#kidney
#heart
#cerebellum
#brain

#Publications with strong Disease-Associations
#Publications with weak Disease-Associations
#Publications with Same-Classification
#Publications with Different-Classification

import csv

# homo sapiens Index
index_Strong_DiseaseAssociation = 8
index_Weak_DiseaseAssociation = 9
index_Strong_Call = 16
index_Weak_Call = 17

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(11, 11))

fig.suptitle('Homo Sapiens & Mus Musculus')

rows = 3
columns = 2

grid = plt.GridSpec(rows, columns, wspace = .5, hspace = .5)

#testis
x1 = []
#Publications with strong Disease-Associations
y1 = []
#Publications with weak Disease-Associations
y2 = []
#Publications with Same-Classification
y3 = []
#Publications with Different-Classification
y4 = []

with open('testis_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x1.append(int(row[0]))
        # Disease association
        y1.append(int(row[index_Strong_DiseaseAssociation]))
        y2.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y3.append(int(row[index_Strong_Call]))
        y4.append(int(row[index_Weak_Call]))
        
plt.subplot(grid[0, 0])
#plt.plot(x1, y1, color='black', label='Publications with strong Disease-Associations')
#plt.plot(x1, y2, color='green', label='Publications with weak Disease-Associations')
plt.plot(x1, y3, color='blue', label='Publications with Same-Classification')
plt.plot(x1, y4, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Testis')

     
#liver
x2 = []
#Publications with strong Disease-Associations
y5 = []
#Publications with weak Disease-Associations
y6 = []
#Publications with Same-Classification
y7 = []
#Publications with Different-Classification
y8 = []

with open('liver_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:   
        x2.append(int(row[0]))
        # Disease association
        y5.append(int(row[index_Strong_DiseaseAssociation]))
        y6.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y7.append(int(row[index_Strong_Call]))
        y8.append(int(row[index_Weak_Call]))

plt.subplot(grid[0, 1])
#plt.plot(x2, y5, color='black', label='Publications with strong Disease-Associations')
#plt.plot(x2, y6, color='green', label='Publications with weak Disease-Associations')
plt.plot(x2, y7, color='blue', label='Publications with Same-Classification')
plt.plot(x2, y8, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Liver')
   
    
#kidney
x3 = []
#Publications with strong Disease-Associations
y9 = []
#Publications with weak Disease-Associations
y10 = []
#Publications with Same-Classification
y11 = []
#Publications with Different-Classification
y12 = []

with open('kidney_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots: 
        x3.append(int(row[0]))
        # Disease association
        y9.append(int(row[index_Strong_DiseaseAssociation]))
        y10.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y11.append(int(row[index_Strong_Call]))
        y12.append(int(row[index_Weak_Call]))
        
plt.subplot(grid[1, 0])
#plt.plot(x3, y9, color='black', label='Publications with strong Disease-Associations')
#plt.plot(x3, y10, color='green', label='Publications with weak Disease-Associations')
plt.plot(x3, y11, color='blue', label='Publications with Same-Classification')
plt.plot(x3, y12, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Kidney')

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -1))
        

#heart
x4 = []
#Publications with strong Disease-Associations
y13 = []
#Publications with weak Disease-Associations
y14 = []
#Publications with Same-Classification
y15 = []
#Publications with Different-Classification
y16 = []

with open('heart_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:  
        x4.append(int(row[0]))
        # Disease association
        y13.append(int(row[index_Strong_DiseaseAssociation]))
        y14.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y15.append(int(row[index_Strong_Call]))
        y16.append(int(row[index_Weak_Call]))
        
plt.subplot(grid[1, 1])
#plt.plot(x4, y13, color='black', label='Publications with strong Disease-Associations')
#plt.plot(x4, y14, color='green', label='Publications with weak Disease-Associations')
plt.plot(x4, y15, color='blue', label='Publications with Same-Classification')
plt.plot(x4, y16, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Heart')
        

#cerebellum
#x5 = []
#Publications with strong Disease-Associations
#y17 = []
#Publications with weak Disease-Associations
#y18 = []
#Publications with Same-Classification
#y19 = []
#Publications with Different-Classification
#y20 = []

#with open('cerebellum_aim2.tsv','r') as csvfile:
    #plots = csv.reader(csvfile, delimiter='\t')
    #for row in plots:   
        #x5.append(int(row[0]))
        # Disease association
        #y17.append(int(row[index_Strong_DiseaseAssociation]))
        #y18.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        #y19.append(int(row[index_Strong_Call]))
        #y20.append(int(row[index_Weak_Call]))
        
#plt.subplot(grid[2, 0])
#plt.plot(x5, y17, color='black', label='Publications with strong Disease-Associations')
#plt.plot(x5, y18, color='green', label='Publications with weak Disease-Associations')
#plt.plot(x5, y19, color='blue', label='Publications with Same-Classification')
#plt.plot(x5, y20, color='orange', label='Publications with Different-Classification')
#plt.xlabel('Year')
#plt.ylabel('# of publications')
#plt.title('Cerebellum')
        

#brain
x6 = []
#Publications with strong Disease-Associations
y21 = []
#Publications with weak Disease-Associations
y22 = []
#Publications with Same-Classification
y23 = []
#Publications with Different-Classification
y24 = []

with open('brain_aim2.tsv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots: 
        x6.append(int(row[0]))
        # Disease association
        #y21.append(int(row[index_Strong_DiseaseAssociation]))
        #y22.append(int(row[index_Weak_DiseaseAssociation]))    
        # Overall call
        y23.append(int(row[index_Strong_Call]))
        y24.append(int(row[index_Weak_Call]))

plt.subplot(grid[2, 1])
#plt.plot(x6, y21, color='black', label='Publications with strong Disease-Associations')
#plt.plot(x6, y22, color='green', label='Publications with weak Disease-Associations')
plt.plot(x6, y23, color='blue', label='Publications with Same-Classification')
plt.plot(x6, y24, color='orange', label='Publications with Different-Classification')
plt.xlabel('Year')
plt.ylabel('# of publications')
plt.title('Brain')
# Out:
# Text(0.5, 1.0, 'Brain')
